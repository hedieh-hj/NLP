# %%
import pandas as pd 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('clean_datasets/clean_all.csv')
df.head()
len(df)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3868\3346992544.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('clean_datasets/clean_all.csv')
# 69346

# %%
#tokenization
def tweet_token(text):
    words_set=text.str.split()
    tokens=[word for word in words_set]
    return tokens

df['tokens']=tweet_token(df['clean_tweet'])
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place   near  near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London  NaN
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London  NaN
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London  NaN
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London  NaN
# 4  My kids can never say they don’t wanna do thei...   NaN  London  NaN
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1     first dose vaccination syringe combating covid
# 2  time forget about covid brexit trump sleep lis...
# 3  rachel you absolutely nailed tonight throughou...
# 4  kids can never say they not wana their homewor...
#
#                                               tokens
# 0  [parliament, covid, vaccine, should, days, not...
# 1  [first, dose, vaccination, syringe, combating,...
# 2  [time, forget, about, covid, brexit, trump, sl...
# 3  [rachel, you, absolutely, nailed, tonight, thr...
# 4  [kids, can, never, say, they, not, wana, their...

# %%
#lemmatize and stemming
import nltk
word_tokenizer = nltk.tokenize.WhitespaceTokenizer()
word_lemmatizer = nltk.stem.WordNetLemmatizer()

def lemmatize_text(text):
    return [word_lemmatizer.lemmatize(word) for word in word_tokenizer.tokenize(text)]
df['lemma']=df['clean_tweet'].apply(lemmatize_text)
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place   near  near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London  NaN
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London  NaN
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London  NaN
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London  NaN
# 4  My kids can never say they don’t wanna do thei...   NaN  London  NaN
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1     first dose vaccination syringe combating covid
# 2  time forget about covid brexit trump sleep lis...
# 3  rachel you absolutely nailed tonight throughou...
# 4  kids can never say they not wana their homewor...
#
#                                               tokens  \
# 0  [parliament, covid, vaccine, should, days, not...
# 1  [first, dose, vaccination, syringe, combating,...
# 2  [time, forget, about, covid, brexit, trump, sl...
# 3  [rachel, you, absolutely, nailed, tonight, thr...
# 4  [kids, can, never, say, they, not, wana, their...
#
#                                                lemma
# 0  [parliament, covid, vaccine, should, day, not,...
# 1  [first, dose, vaccination, syringe, combating,...
# 2  [time, forget, about, covid, brexit, trump, sl...
# 3  [rachel, you, absolutely, nailed, tonight, thr...
# 4  [kid, can, never, say, they, not, wana, their,...

# %%
#lemma_sentence
df['lemma_sentence'] = df['lemma'].apply(lambda x: ' '.join(x))
df.head()
# Out:
#    created_at              user_id         username  \
# 0  2021-01-06            293175196        sjtafalla
# 1  2021-01-06           1591779799        ellieelif
# 2  2021-01-06            215143656     danananarama
# 3  2021-01-06            336462129  veronica_foote_
# 4  2021-01-06  1063705581133934593           5herii
#
#                                                tweet place   near  near  \
# 0  UK Parliament: 2nd Covid Vaccine should be 21 ...   NaN  London  NaN
# 1  First dose of vaccination 💉 5/1/2021..to comba...   NaN  London  NaN
# 2  Time to forget about #COVID, #Brexit and #Trum...   NaN  London  NaN
# 3  @doctor_oxford Rachel you absolutely nailed it...   NaN  London  NaN
# 4  My kids can never say they don’t wanna do thei...   NaN  London  NaN
#
#                                          clean_tweet  \
# 0  parliament covid vaccine should days not weeks...
# 1     first dose vaccination syringe combating covid
# 2  time forget about covid brexit trump sleep lis...
# 3  rachel you absolutely nailed tonight throughou...
# 4  kids can never say they not wana their homewor...
#
#                                               tokens  \
# 0  [parliament, covid, vaccine, should, days, not...
# 1  [first, dose, vaccination, syringe, combating,...
# 2  [time, forget, about, covid, brexit, trump, sl...
# 3  [rachel, you, absolutely, nailed, tonight, thr...
# 4  [kids, can, never, say, they, not, wana, their...
#
#                                                lemma  \
# 0  [parliament, covid, vaccine, should, day, not,...
# 1  [first, dose, vaccination, syringe, combating,...
# 2  [time, forget, about, covid, brexit, trump, sl...
# 3  [rachel, you, absolutely, nailed, tonight, thr...
# 4  [kid, can, never, say, they, not, wana, their,...
#
#                                       lemma_sentence
# 0  parliament covid vaccine should day not week c...
# 1     first dose vaccination syringe combating covid
# 2  time forget about covid brexit trump sleep lis...
# 3  rachel you absolutely nailed tonight throughou...
# 4  kid can never say they not wana their homework...

# %%
import nltk

# Download necessary NLTK data
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\PC/nltk_data', 'C:\\Users\\PC\\AppData\\Local\\Programs\\Python\\Python310\\nltk_data', 'C:\\Users\\PC\\AppData\\Local\\Programs\\Python\\Python310\\share\\nltk_data', 'C:\\Users\\PC\\AppData\\Local\\Programs\\Python\\Python310\\lib\\nltk_data', 'C:\\Users\\PC\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'C:/Users/PC/nltk_data', 'nltk_data', 'nltk_data', 'nltk_data']

# %%
import spacy
import pandas as pd
from nltk.corpus import wordnet

# Load the English language model
nlp = spacy.load("en_core_web_sm")

# Function to convert spaCy POS tags to WordNet POS tags
def convert_wordnet_tag(tag):
    if tag == "ADJ":
        return wordnet.ADJ
    elif tag == "VERB":
        return wordnet.VERB
    elif tag == "NOUN":
        return wordnet.NOUN
    elif tag == "ADV":
        return wordnet.ADV
    else:
        return None

# Function to perform POS tagging using spaCy and convert to WordNet tags
def spacy_pos_tag_set(tweet):
    # Process the tweet using spaCy
    doc = nlp(tweet)
    # Extract words and their POS tags
    tagged_words = [(token.text, convert_wordnet_tag(token.pos_)) for token in doc]
    return tagged_words

# Apply the function to the 'clean_tweet' column
df['pos_tag'] = df['clean_tweet'].apply(spacy_pos_tag_set)

# Print or inspect the updated DataFrame
print(df)
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
# [69346 rows x 12 columns]

# %%
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
# [69346 rows x 12 columns]

# %%
#create lemma sentence with pos-tags
def handle_lemma(pos_tweet):
    lemma_set = " "
    for word, pos in pos_tweet:
        if not pos: 
            lemma = word
            lemma_set = lemma_set + " " + lemma
        else:  
            lemma = stem_lemmatizer.lemmatize(word, pos=pos)
            lemma_set = lemma_set + " " + lemma
    return lemma_set
df['pos_tag'].apply(handle_lemma)
    
df['lemma_sentence(with POS)'] = df['pos_tag'].apply(handle_lemma)
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
#                                 lemma_sentence(with POS)
# 0        parliament covid vaccine should day not week...
# 1            first dose vaccination syringe combat covid
# 2        time forget about covid brexit trump sleep l...
# 3        rachel you absolutely nail tonight throughou...
# 4        kid can never say they not wana their homewo...
# ...                                                  ...
# 69341    very little interest politician media how we...
# 69342    break health secretary matt hancock has anno...
# 69343    hundred flight full indian corona come acros...
# 69344    sadiq khan ask for vaccine blitz variant hit...
# 69345    this not covid reality rather than brexit re...
#
# [69346 rows x 13 columns]

# %%
#save as csv
df.to_csv('Further_clean_datasets/further_clean_all.csv',index = False, encoding='utf_8_sig')

# %%
#split into 3 steps
import datetime
df['created_at'] = pd.to_datetime(df['created_at'] , utc=True).dt.date
further_step_one = df[(df['created_at']) < datetime.date(2021,3,8)].reset_index(drop=True)
print("step_one:",len(further_step_one))
# Out:
# step_one: 29934

# %%
further_step_two = df[((df['created_at']) >= datetime.date(2021,3,8)) & ((df['created_at']) < datetime.date(2021,5,17))].reset_index(drop=True)
print("step_two:",len(further_step_two))
# Out:
# step_two: 20486

# %%
further_step_three= df[((df['created_at']) >= datetime.date(2021,5,17)) & ((df['created_at']) <= datetime.date(2021,7,18))].reset_index(drop=True)
print("step_three:",len(further_step_three))
len(further_step_one)+len(further_step_two)+len(further_step_three)
# Out:
# step_three: 18926
# 69346

# %%
further_step_one.to_csv('Further_clean_datasets/further_clean_step1.csv',index = False, encoding='utf_8_sig')
further_step_two.to_csv('Further_clean_datasets/further_clean_step2.csv',index = False, encoding='utf_8_sig')
further_step_three.to_csv('Further_clean_datasets/further_clean_step3.csv',index = False, encoding='utf_8_sig')

# %%
#sentiwordnet analysis
#reference: https://github.com/harika-bonthu/Lexicon-based-SentimentAnalysis/blob/main/lexicon_based_sentiment_analysis.ipynb
nltk.download('sentiwordnet')
from nltk.corpus import sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()


def sentiwordnetanalysis(pos_data):
    sentiment = 0
    tokens_count = 0
    for word, pos in pos_data:
        if not pos:
            continue
        lemma = wordnet_lemmatizer.lemmatize(word, pos=pos)
        if not lemma:
            continue
        
        synsets = wordnet.synsets(lemma, pos=pos)
        if not synsets:
            continue

        synset = synsets[0] #only take the most common meaning
        swn_synset = swn.senti_synset(synset.name())
        sentiment += swn_synset.pos_score() - swn_synset.neg_score()
        tokens_count += 1
    if not tokens_count:
        return 0
    else:
        return sentiment

df['sentiword_analysis']=df['pos_tag'].apply(sentiwordnetanalysis)
df
# Out:
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
#                                 lemma_sentence(with POS)  sentiword_analysis
# 0        parliament covid vaccine should day not week...               0.125
# 1            first dose vaccination syringe combat covid              -0.125
# 2        time forget about covid brexit trump sleep l...               0.250
# 3        rachel you absolutely nail tonight throughou...               1.375
# 4        kid can never say they not wana their homewo...               0.125
# ...                                                  ...                 ...
# 69341    very little interest politician media how we...               0.625
# 69342    break health secretary matt hancock has anno...               0.875
# 69343    hundred flight full indian corona come acros...               0.750
# 69344    sadiq khan ask for vaccine blitz variant hit...               0.000
# 69345    this not covid reality rather than brexit re...               0.000
#
# [69346 rows x 14 columns]

# %%
#VADER--low speed--use further clean datasets
sentiment_analyzer = SentimentIntensityAnalyzer()
def vaderSentiment_method(df):
    sentiment_analyzer = SentimentIntensityAnalyzer()
    snt_score = sentiment_analyzer.polarity_scores(df['lemma_sentence(with POS)'])
    return snt_score['compound'] 

df['vader_score'] = df.apply(vaderSentiment_method, axis=1)
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
#                                 lemma_sentence(with POS)  sentiword_analysis  \
# 0        parliament covid vaccine should day not week...               0.125
# 1            first dose vaccination syringe combat covid              -0.125
# 2        time forget about covid brexit trump sleep l...               0.250
# 3        rachel you absolutely nail tonight throughou...               1.375
# 4        kid can never say they not wana their homewo...               0.125
# ...                                                  ...                 ...
# 69341    very little interest politician media how we...               0.625
# 69342    break health secretary matt hancock has anno...               0.875
# 69343    hundred flight full indian corona come acros...               0.750
# 69344    sadiq khan ask for vaccine blitz variant hit...               0.000
# 69345    this not covid reality rather than brexit re...               0.000
#
#        vader_score
# 0          -0.0572
# 1          -0.3400
# 2          -0.2263
# 3           0.6124
# 4           0.6573
# ...            ...
# 69341      -0.3151
# 69342       0.0000
# 69343      -0.2023
# 69344       0.0000
# 69345       0.0000
#
# [69346 rows x 15 columns]

# %%
#Textblob
from textblob import TextBlob

def Polarity_score(tweet):
    return TextBlob(tweet).sentiment.polarity

def Subjectivity_score(tweet):
    return TextBlob(tweet).sentiment.subjectivity

df['textblob_polarity'] = df['lemma_sentence(with POS)'].apply(Polarity_score) 
df
# Out:
#        created_at              user_id         username  \
# 0      2021-01-06            293175196        sjtafalla
# 1      2021-01-06           1591779799        ellieelif
# 2      2021-01-06            215143656     danananarama
# 3      2021-01-06            336462129  veronica_foote_
# 4      2021-01-06  1063705581133934593           5herii
# ...           ...                  ...              ...
# 69341  2021-05-20  1161700993840680961     PhilipCrook9
# 69342  2021-05-19            146596633     edwardjsault
# 69343  2021-05-19            235304684        phoTomics
# 69344  2021-05-17   726443182997835778     SarahClift10
# 69345  2021-05-17            316385442       theveindoc
#
#                                                    tweet  \
# 0      UK Parliament: 2nd Covid Vaccine should be 21 ...
# 1      First dose of vaccination 💉 5/1/2021..to comba...
# 2      Time to forget about #COVID, #Brexit and #Trum...
# 3      @doctor_oxford Rachel you absolutely nailed it...
# 4      My kids can never say they don’t wanna do thei...
# ...                                                  ...
# 69341  Very little interest by politicians and media ...
# 69342  #BREAKING Health Secretary Matt Hancock has an...
# 69343  “Hundreds of flights full of Indian corona” co...
# 69344  Sadiq Khan asks for vaccine blitz in variant-h...
# 69345  Is this not Covid reality rather than Brexit r...
#
#                                                    place  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 69341  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69342  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69343  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69344  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
# 69345  {'type': 'Feature', 'bbox': [-1.476463, 50.883...
#
#                       near  near  \
# 0                    London  NaN
# 1                    London  NaN
# 2                    London  NaN
# 3                    London  NaN
# 4                    London  NaN
# ...                     ...  ...
# 69341  Southampton, England  NaN
# 69342  Southampton, England  NaN
# 69343  Southampton, England  NaN
# 69344  Southampton, England  NaN
# 69345  Southampton, England  NaN
#
#                                              clean_tweet  \
# 0      parliament covid vaccine should days not weeks...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kids can never say they not wana their homewor...
# ...                                                  ...
# 69341  very little interest politicians media how wel...
# 69342  breaking health secretary matt hancock has ann...
# 69343  hundreds flights full indian corona comes acro...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                   tokens  \
# 0      [parliament, covid, vaccine, should, days, not...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kids, can, never, say, they, not, wana, their...
# ...                                                  ...
# 69341  [very, little, interest, politicians, media, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundreds, flights, full, indian, corona, come...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                                    lemma  \
# 0      [parliament, covid, vaccine, should, day, not,...
# 1      [first, dose, vaccination, syringe, combating,...
# 2      [time, forget, about, covid, brexit, trump, sl...
# 3      [rachel, you, absolutely, nailed, tonight, thr...
# 4      [kid, can, never, say, they, not, wana, their,...
# ...                                                  ...
# 69341  [very, little, interest, politician, medium, h...
# 69342  [breaking, health, secretary, matt, hancock, h...
# 69343  [hundred, flight, full, indian, corona, come, ...
# 69344  [sadiq, khan, asks, for, vaccine, blitz, varia...
# 69345  [this, not, covid, reality, rather, than, brex...
#
#                                           lemma_sentence  \
# 0      parliament covid vaccine should day not week c...
# 1         first dose vaccination syringe combating covid
# 2      time forget about covid brexit trump sleep lis...
# 3      rachel you absolutely nailed tonight throughou...
# 4      kid can never say they not wana their homework...
# ...                                                  ...
# 69341  very little interest politician medium how wel...
# 69342  breaking health secretary matt hancock ha anno...
# 69343  hundred flight full indian corona come across ...
# 69344  sadiq khan asks for vaccine blitz variant hit ...
# 69345  this not covid reality rather than brexit reality
#
#                                                  pos_tag  \
# 0      [(parliament, None), (covid, None), (vaccine, ...
# 1      [(first, r), (dose, None), (vaccination, n), (...
# 2      [(time, n), (forget, v), (about, None), (covid...
# 3      [(rachel, None), (you, None), (absolutely, r),...
# 4      [(kids, n), (can, None), (never, r), (say, v),...
# ...                                                  ...
# 69341  [(very, r), (little, a), (interest, n), (polit...
# 69342  [(breaking, v), (health, n), (secretary, None)...
# 69343  [(hundreds, n), (flights, n), (full, a), (indi...
# 69344  [(sadiq, None), (khan, None), (asks, v), (for,...
# 69345  [(this, None), (not, None), (covid, a), (reali...
#
#                                 lemma_sentence(with POS)  sentiword_analysis  \
# 0        parliament covid vaccine should day not week...               0.125
# 1            first dose vaccination syringe combat covid              -0.125
# 2        time forget about covid brexit trump sleep l...               0.250
# 3        rachel you absolutely nail tonight throughou...               1.375
# 4        kid can never say they not wana their homewo...               0.125
# ...                                                  ...                 ...
# 69341    very little interest politician media how we...               0.625
# 69342    break health secretary matt hancock has anno...               0.875
# 69343    hundred flight full indian corona come acros...               0.750
# 69344    sadiq khan ask for vaccine blitz variant hit...               0.000
# 69345    this not covid reality rather than brexit re...               0.000
#
#        vader_score  textblob_polarity
# 0          -0.0572           0.000000
# 1          -0.3400           0.250000
# 2          -0.2263           0.000000
# 3           0.6124           0.300000
# 4           0.6573           0.025000
# ...            ...                ...
# 69341      -0.3151          -0.153472
# 69342       0.0000           0.375000
# 69343      -0.2023           0.300000
# 69344       0.0000           0.000000
# 69345       0.0000           0.000000
#
# [69346 rows x 16 columns]

# %%
##save as csv
df.to_csv('unsupervised_datasets/lexicon_all.csv',index = False, encoding='utf_8_sig')

# %%
#split into 3 steps
import datetime
df['created_at'] = pd.to_datetime(df['created_at'] , utc=True).dt.date
lexicon_step_one = df[(df['created_at']) < datetime.date(2021,3,8)].reset_index(drop=True)
print("step_one:",len(lexicon_step_one))
# Out:
# step_one: 29934

# %%
lexicon_step_two = df[((df['created_at']) >= datetime.date(2021,3,8)) & ((df['created_at']) < datetime.date(2021,5,17))].reset_index(drop=True)
print("step_two:",len(lexicon_step_two))
# Out:
# step_two: 20486

# %%
lexicon_step_three= df[((df['created_at']) >= datetime.date(2021,5,17)) & ((df['created_at']) <= datetime.date(2021,7,18))].reset_index(drop=True)
print("step_three:",len(lexicon_step_three))
# Out:
# step_three: 18926

# %%
#merge three datasets
dfs=[lexicon_step_one,lexicon_step_two,lexicon_step_three]
dfs=pd.concat(dfs)
dfs=dfs.reset_index(drop=True)

# %%
lexicon_step_one.to_csv('unsupervised_datasets/lexicon_step1.csv',index = False, encoding='utf_8_sig')
lexicon_step_two.to_csv('unsupervised_datasets/lexicon_step2.csv',index = False, encoding='utf_8_sig')
lexicon_step_three.to_csv('unsupervised_datasets/lexicon_step3.csv',index = False, encoding='utf_8_sig')
